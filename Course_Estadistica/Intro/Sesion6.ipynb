# %%
import scipy.stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('bicicletas-compartidas.csv')

# %% [markdown]
# Categoricas

# %%
df.columns
# Out:
# Index(['fecha', 'bicis-compartidas', 'temp-obs', 'sens-temp', 'hum', 'viento',
#        'codigo-clima', 'festivo', 'findesemana', 'cuartil-ano'],
#       dtype='object')

# %%
y = df['cuartil-ano'].apply(lambda x:'cuartil-' + str(int(x)))

# %%
fig , ax = plt.subplots()
ax.bar(y.value_counts().index,y.value_counts())
ax.set_xlabel('Cuartiles del año')
ax.set_ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
fig , ax = plt.subplots()
ax.bar(y.value_counts().index,y.value_counts())
ax.set_xlabel('Cuartiles del año')
ax.set_ylabel('Frecuencia')
ax.patches[2].set_facecolor('red')

# %%
fig , ax = plt.subplots()
ax.pie(y.value_counts(), labels = y.value_counts().index)
ax.set_title('Diagrama de pie')
# Out:
# Text(0.5, 1.0, 'Diagrama de pie')

# %% [markdown]
# Numericas

# %%
y = df['viento']

# %%
fig , ax = plt.subplots()
ax.hist(y, bins = 30)
ax.set_xlabel('Viento')
ax.set_ylabel('Frecuencias')
plt.axvline(np.mean(y),c = 'r', linestyle = '--', label = 'Promedio')
plt.axvline(np.mean(y) + np.std(y),c = 'k', linestyle = '--', label = '+1-desviacion')
plt.axvline(np.mean(y) - np.std(y),c = 'k', linestyle = '--', label = '-1-desviacion')
ax.legend()

# %%
y = df['bicis-compartidas']
fig, ax = plt.subplots()
sns.boxplot(x= 'cuartil-ano',y='bicis-compartidas', data=df)

# %%
fig, ax = plt.subplots()
ax.scatter(df['viento'], df['bicis-compartidas'],alpha = 0.03)
ax.set_title('Distribucion conjunta de Viento y Bicis-Comaprtidas')
ax.set_xlabel('Viento')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-64af4b414bef> in <module>
#       1 fig, ax = plt.subplots()
#       2 ax.scatter(df['viento'], df['bicis-compartidas'],alpha = 0.03)
# ----> 3 ax.title('Distribucion conjunta de Viento y Bicis-Comaprtidas')
#       4 ax.set_xlabel('Viento')
#
# TypeError: 'Text' object is not callable
